# %%
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q tf-models-official transformers tensorflow_text

# %%
cd /content/drive/MyDrive/TianChi/esim
# Out:
# /content/drive/.shortcut-targets-by-id/1yzcb4wXOi64yqQnKJPvfDsk41CO-6yuq/TianChi/esim

# %%
# !nvidia-smi
# Out:
# Wed Mar  3 06:42:12 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8    10W /  70W |      3MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !python training.py
# Out:
# start training
# 	* Loading training data...
# 	* Loading val data...
# 313
# 20000
# Avg. batch proc. AUC: 0.5221, loss: 0.6971: 100% 313/313 [00:04<00:00, 77.19it/s]
# 	* Validation loss before training: 0.6971, accuracy: 46.9700%, AUC: 0.5221
#
#
#  ==================== Training ESIM model on device: cuda:0 ====================
# * Training epoch 1:
# Avg. batch proc. time: 0.0344s, loss: 0.5077, AUC: 0.8061: 100% 1250/1250 [00:44<00:00, 28.09it/s]
# -> Training time: 44.4942s, loss = 0.5077, accuracy: 74.9400%, AUC: 0.8061
#
# * Validation for epoch 1:
# Avg. batch proc. AUC: 0.8647, loss: 0.4643: 100% 313/313 [00:04<00:00, 78.17it/s]
# -> Valid. time: 4.0043s, loss: 0.4643, accuracy: 76.9050%, AUC: 0.8647
#
# * Training epoch 2:
# Avg. batch proc. time: 0.0355s, loss: 0.4459, AUC: 0.8558:  56% 695/1250 [00:25<00:20, 27.20it/s]Traceback (most recent call last):
#   File "training.py", line 172, in <module>
#     training(checkpoint)
#   File "training.py", line 126, in training
# ...

# %%
cd /content/drive/MyDrive/TianChi
# Out:
# /content/drive/MyDrive/TianChi

# %%
# !git pull https://d294270681:DMHsgr001@github.com/d294270681/TianChi.git
# Out:
# From https://github.com/d294270681/TianChi
#  * branch            HEAD       -> FETCH_HEAD
# Already up to date.

# %%
# !git add
# Out:
# ^C
